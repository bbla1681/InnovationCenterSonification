# %% [markdown]
# # Imports

# %%
from midiutil import MIDIFile 
import pandas as pd
import numpy as np
from sofar_api import get_data
import matplotlib.pylab as plt
from sklearn.preprocessing import normalize
import pygame
from audiolazy import str2midi, midi2str
from data_to_midi import df_to_midi, api_to_midi
import mido


#Had to chnage the library imports from parts of the audio lazy library.
# In lazy_analysis.py changed from collections import Sequence, Iterable -> from collections.abc import Sequence, Iterable
# In lazy_core.py changed from collections import, Iterable -> from collections.abc import Iterable
# In lazy_stream.py changed from collections import, Iterable -> from collections.abc import Iterable
# In lazy_misc.py changed from collections import, Iterable -> from collections.abc import Iterable
# In lazy_filters.py changed from collections import, Iterable -> from collections.abc import Iterable
# In lazy_poly.py changed from collections import, Iterable -> from collections.abc import Iterable
# In lazy_itertools.py changed from collections import, Iterable -> from collections.abc import Iterable
# Out:
# pygame 2.5.2 (SDL 2.28.3, Python 3.11.2)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %% [markdown]
# # Using Data From CSV

# %%
#import csv file into pandas dataframe
df = pd.read_csv("./data/waves.csv")

# %%
#display shape and first 5 rows of dataframe
print(df.shape)
df.head()
# Out:
# (40, 381)
#    Battery Voltage (V)  Power (W)  Humidity (%rel)  Epoch Time  \
# 0                  4.1      -0.24             46.4  1699588561
# 1                  4.1      -0.24             46.4  1699586761
# 2                  4.1      -0.19             44.8  1699584961
# 3                  4.1      -0.19             44.8  1699583161
# 4                  4.1      -0.20             42.4  1699581361
#
#    Significant Wave Height (m)  Peak Period (s)  Mean Period (s)  \
# 0                         0.07             7.30             4.82
# 1                         0.05             6.82             4.50
# 2                         0.05            25.60             4.24
# 3                         0.06             6.82             4.12
# 4                         0.06             6.82             3.20
#
#    Peak Direction (deg)  Peak Directional Spread (deg)  Mean Direction (deg)  \
# 0               128.327                         29.382               136.457
# 1               133.725                         29.243               137.324
# 2               228.447                         76.229               141.405
# 3               128.509                         21.528               132.368
# 4               131.668                         19.921               137.342
#
#    ...  Partition0 Mean Direction (deg)  \
# 0  ...                                -
# 1  ...                                -
# 2  ...                                -
# 3  ...                                -
# 4  ...                                -
#
#    Partition0 Mean Directional Spread (deg)  Partition1 Start Frequency (hz)  \
# 0                                         -                                -
# 1                                         -                                -
# 2                                         -                                -
# 3                                         -                                -
# 4                                         -                                -
#
#   Partition1 End Frequency (hz) Partition1 Significant Wave Height (m)  \
# 0                             -                                      -
# 1                             -                                      -
# 2                             -                                      -
# 3                             -                                      -
# 4                             -                                      -
#
#   Partition1 Mean Period (s) Partition1 Mean Direction (deg)  \
# 0                          -                               -
# 1                          -                               -
# 2                          -                               -
# 3                          -                               -
# 4                          -                               -
#
#   Partition1 Mean Directional Spread (deg) Mean Barometric Pressure (hPa)  \
# 0                                        -                              -
# 1                                        -                              -
# 2                                        -                              -
# 3                                        -                              -
# 4                                        -                              -
#
#   Processing Source
# 0          embedded
# 1          embedded
# 2          embedded
# 3          embedded
# 4          embedded
#
# [5 rows x 381 columns]

# %%
#Data set has many empty columns. Drop them.
small_df = df.drop(columns=df.columns[13:], axis=1)
small_df.head()
# Out:
#    Battery Voltage (V)  Power (W)  Humidity (%rel)  Epoch Time  \
# 0                  4.1      -0.24             46.4  1699588561
# 1                  4.1      -0.24             46.4  1699586761
# 2                  4.1      -0.19             44.8  1699584961
# 3                  4.1      -0.19             44.8  1699583161
# 4                  4.1      -0.20             42.4  1699581361
#
#    Significant Wave Height (m)  Peak Period (s)  Mean Period (s)  \
# 0                         0.07             7.30             4.82
# 1                         0.05             6.82             4.50
# 2                         0.05            25.60             4.24
# 3                         0.06             6.82             4.12
# 4                         0.06             6.82             3.20
#
#    Peak Direction (deg)  Peak Directional Spread (deg)  Mean Direction (deg)  \
# 0               128.327                         29.382               136.457
# 1               133.725                         29.243               137.324
# 2               228.447                         76.229               141.405
# 3               128.509                         21.528               132.368
# 4               131.668                         19.921               137.342
#
#    Mean Directional Spread (deg)  Latitude (deg)  Longitude (deg)
# 0                         56.342        37.87463       -122.48137
# 1                         46.913        37.87463       -122.48137
# 2                         62.622        37.87463       -122.48138
# 3                         51.119        37.87463       -122.48138
# 4                         53.854        37.87463       -122.48138

# %%
small_df.shape
# Out:
# (40, 13)

# %%
angles = small_df['Peak Direction (deg)']

# %%
xlist = [np.cos(ang) for ang in angles]
ylist = [np.sin(ang) for ang in angles]

# %%
#Visualization of the direction the waves are coming from
for x, y in zip(xlist, ylist):
  plt.plot([0,x],[0,y])
plt.show()

# %%
def map_value(value, min_value, max_value, min_result, max_result):
 #maps value (or array of values) from one range to another
 
 result = min_result + (value - min_value)/(max_value - min_value)*(max_result - min_result)
 return result

# %%
small_df = df.drop(columns=df.columns[13:], axis=1)
height = small_df["Significant Wave Height (m)"].values
times = small_df["Mean Period (s)"].values
for i in range(1,len(times)):
    times[i] += times[i-1]
times
# Out:
# array([  4.82,   9.32,  13.56,  17.68,  20.88,  24.1 ,  27.92,  30.82,
#         33.74,  36.7 ,  39.86,  42.92,  45.96,  49.62,  53.6 ,  57.94,
#         61.62,  64.96,  69.18,  72.24,  75.6 ,  79.32,  83.9 ,  88.9 ,
#         94.84, 100.52, 106.42, 113.42, 119.8 , 125.3 , 131.52, 136.7 ,
#        143.02, 148.8 , 154.24, 159.9 , 165.54, 171.84, 178.3 , 183.46])

# %%
#Visualize Peak Wave over a period of time 
# normalize the data
plt.scatter(times, height)
plt.xlabel("Time (s)")
plt.ylabel("Height (m)")
plt.show()

# %%
duration_beats = 60
t_data = map_value(times, 0, max(times), 0,duration_beats)

# %%
bpm = 60  
duration_sec = duration_beats*60/bpm  
print('Duration:', duration_sec, 'seconds')
# Out:
# Duration: 60.0 seconds

# %%
#Regular Peak Times
#peak_times = small_df["Peak Period (s)"]
#normalized_peak_times = map_value(peak_times, min(peak_times), max(peak_times), 0, 1)
#plt.scatter(times, (normalized_peak_times))
#plt.xlabel("Time (s)")
#plt.ylabel("Peak Times (s)")
#plt.show()

#It looks like theres a reverse correlation between the two graphs

# %%
#Inverse Peak Times. Decide which to use
peak_times = small_df["Peak Period (s)"]
normalized_peak_times = map_value(peak_times, min(peak_times), max(peak_times), 0, 1)
normalized_peak_times = 1 - normalized_peak_times
plt.scatter(times,(normalized_peak_times))
plt.xlabel("Time (s)")
plt.ylabel("Peak Times (s)")
plt.show()

# %%
normalized_height = map_value(height, min(height), max(height), 0, 1)
plt.scatter(times,(normalized_height))
plt.xlabel("Time (s)")
plt.ylabel("Heights (m)")
plt.show()

# %%
#Deicide Which To Use
#note_names = ['C2','D2','E2','F2','G2','A2','B2',
#             'C3','D3','E3','F3','G3','A3','B3',
#             'C4','D4','E4','F4','G4','A4','B4']

# %%
note_names = ['C2','D2','E2','G2','A2',
             'C3','D3','E3','G3','A3',
             'C4','D4','E4','G4','A4']

# %%
#note_names = ['C1','C2','G2',
#            'C3','E3','G3','A3','B3',
#             'D4','E4','G4','A4','B4',
#             'D5','E5','G5','A5','B5',
#             'D6','E6','F#6','G6','A6']

# %%
note_midis = [str2midi(n) for n in note_names] 
n_notes = len(note_midis)

# %%
midi_data = []
for i in range(len(normalized_height)):
    note_index = round((map_value(normalized_height[i], 0, 1, n_notes-1, 0))) 
    midi_data.append(note_midis[note_index])
plt.scatter(t_data, midi_data, s=50*normalized_height)
plt.xlabel('time [beats]')
plt.ylabel('midi note numbers')
plt.show()

# %%
vel_min,vel_max = 30,80   #minimum and maximum note velocity
vel_data = []
for i in range(len(normalized_peak_times)):
    note_velocity = round(map_value(normalized_peak_times[i],0,1,vel_min, vel_max)) 
    vel_data.append(note_velocity)
    


plt.scatter(times,(normalized_height))
plt.xlabel("Time (s)")
plt.ylabel("Heights (m)")
plt.show()

plt.scatter(times,(normalized_peak_times))
plt.xlabel("Time (s)")
plt.ylabel("Peak Times (s)")
plt.show()

plt.scatter(t_data, midi_data, s=vel_data)
plt.xlabel('time [beats]')
plt.ylabel('midi note numbers')
plt.show()

# %%
#create midi file object, add tempo
my_midi_file = MIDIFile(1) #one track 
my_midi_file.addTempo(track=0, time=0, tempo=bpm) 
filename = "test_wave_music"
#add midi notes
for i in range(len(t_data)):
    my_midi_file.addNote(track=0, channel=0, time=t_data[i], pitch=midi_data[i], volume=vel_data[i], duration=2)
#create and save the midi file itself
with open(filename + '.mid', "wb") as f:
    my_midi_file.writeFile(f)

# %%
pygame.init()
pygame.mixer.music.load(filename + '.mid')
pygame.mixer.music.play()

# %%
pygame.mixer.music.stop() #run this to stop, it's the only way!

# %% [markdown]
# # Using Pulled Data From API

# %%
api_df = get_data(index=1,lim=100,
start='2023-11-09',
end='2023-11-10')

api_df.head()
# Out:
#    significantWaveHeight  peakPeriod  meanPeriod  peakDirection  \
# 0                   0.12        6.82        4.16        142.672
# 1                   0.08        9.30        4.60        145.967
# 2                   0.08       10.24        3.78        141.119
# 3                   0.08        4.44        3.60        143.785
# 4                   0.05        6.82        4.42        135.000
#
#    peakDirectionalSpread  meanDirection  meanDirectionalSpread  \
# 0                 28.047        143.941                 47.983
# 1                 30.201        143.560                 51.308
# 2                 43.390        138.938                 54.139
# 3                 19.613        143.150                 53.406
# 4                 28.321        137.054                 56.090
#
#                   timestamp  latitude  longitude processing_source
# 0  2023-11-09T00:26:01.000Z  37.87462 -122.48138          embedded
# 1  2023-11-09T00:56:01.000Z  37.87462 -122.48138          embedded
# 2  2023-11-09T01:26:01.000Z  37.87462 -122.48138          embedded
# 3  2023-11-09T01:56:01.000Z  37.87462 -122.48138          embedded
# 4  2023-11-09T02:26:01.000Z  37.87462 -122.48137          embedded

# %%
def map_value(value, min_value, max_value, min_result, max_result):
 #maps value (or array of values) from one range to another
 
 result = min_result + (value - min_value)/(max_value - min_value)*(max_result - min_result)
 return result

# %%
api_height = api_df["significantWaveHeight"].values
api_times = api_df["meanPeriod"].values
for i in range(1,len(api_times)):
    api_times[i] += api_times[i-1]
api_times
# Out:
# array([  4.16,   8.76,  12.54,  16.14,  20.56,  24.58,  28.88,  34.2 ,
#         38.72,  42.8 ,  47.42,  52.5 ,  56.62,  61.82,  67.  ,  70.94,
#         76.1 ,  82.56,  88.86,  94.5 , 100.16, 105.6 , 111.38, 117.7 ,
#        122.88, 129.1 , 134.6 , 140.98, 147.98, 153.88, 159.56, 165.5 ,
#        170.5 , 175.08, 178.8 , 182.16, 185.22, 189.44, 192.78, 196.46,
#        200.8 , 204.78, 208.44, 211.48, 214.54, 217.7 , 220.66, 223.58])

# %%
#Visualize Peak Wave over a period of time 
# normalize the data
plt.scatter(api_times, api_height)
plt.xlabel("Time (s)")
plt.ylabel("Height (m)")
plt.show()

# %%
duration_beats = 60
api_t_data = map_value(api_times, 0, max(api_times), 0,duration_beats)

# %%
bpm = 60  
duration_sec = duration_beats*60/bpm  
print('Duration:', duration_sec, 'seconds')
# Out:
# Duration: 60.0 seconds

# %%
#Inverse Peak Times. Decide which to use
api_peak_times = api_df["peakPeriod"]
api_normalized_peak_times = map_value(api_peak_times, min(api_peak_times), max(api_peak_times), 0, 1)
api_normalized_peak_times = 1-api_normalized_peak_times
plt.scatter(api_times,(api_normalized_peak_times))
plt.xlabel("Time (s)")
plt.ylabel("Peak Times (s)")
plt.show()

# %%
#Inverse heights
api_normalized_height = map_value(api_height, min(api_height), max(api_height), 0, 1)
plt.scatter(api_times,(api_normalized_height))
plt.xlabel("Time (s)")
plt.ylabel("Heights (m)")
plt.show()

# %%
note_names = ['C2','D2','E2','G2','A2',
             'C3','D3','E3','G3','A3',
             'C4','D4','E4','G4','A4']

# %%
note_midis = [str2midi(n) for n in note_names] 
n_notes = len(note_midis)

# %%
api_midi_data = []
for i in range(len(api_normalized_height)):
    api_note_index = round((map_value(api_normalized_height[i], 0, 1, n_notes-1, 0))) 
    api_midi_data.append(note_midis[api_note_index])
plt.scatter(api_t_data, api_midi_data, s=50*api_normalized_height)
plt.xlabel('time [beats]')
plt.ylabel('midi note numbers')
plt.show()

# %%
vel_min,vel_max = 30,80   #minimum and maximum note velocity
api_vel_data = []
for i in range(len(api_normalized_peak_times)):
    note_velocity = (round(map_value(api_normalized_peak_times[i],0,1,vel_min, vel_max))) 
    api_vel_data.append(note_velocity)
    
plt.scatter(api_times, api_height)
plt.xlabel("Time (s)")
plt.ylabel("Height (m)")
plt.show()

plt.scatter(api_times,(api_normalized_peak_times))
plt.xlabel("Time (s)")
plt.ylabel("Peak Times (s)")
plt.show()

plt.scatter(api_t_data, api_midi_data, s=api_vel_data)
plt.xlabel('time [beats]')
plt.ylabel('midi note numbers')
plt.show()

# %%
#create midi file object, add tempo
my_midi_file = MIDIFile(1) #one track 
my_midi_file.addTempo(track=0, time=0, tempo=bpm) 
api_filename = "api_test_wave_music"
#add midi notes
for i in range(len(api_t_data)):
    my_midi_file.addNote(track=0, channel=0, time=api_t_data[i], pitch=api_midi_data[i], volume=api_vel_data[i], duration=2)
#create and save the midi file itself
with open(api_filename + '.mid', "wb") as f:
    my_midi_file.writeFile(f)

# %%
pygame.init()
pygame.mixer.music.load(api_filename + '.mid')
pygame.mixer.music.play()

# %%
pygame.mixer.music.stop() #run this to stop, it's the only way!

# %% [markdown]
# # Testing API Function

# %%
notes = ['C2','D2','E2','G2','A2',
             'C3','D3','E3','G3','A3',
             'C4','D4','E4','G4','A4']
note_column = "significantWaveHeight"
velocity_column = "peakPeriod"
time_column = "meanPeriod"
beats = 60
bpm = 60
vel_min,vel_max = 50,127
start='2023-11-09'
end='2023-11-10'

# %%
filename= "api_test_wave_music"
api_to_midi(start, end, filename, note_column, velocity_column, time_column, beats,bpm, notes, vel_min, vel_max)

# %% [markdown]
# # Adding Pan

# %%
def map_value(value, min_value, max_value, min_result, max_result):
 #maps value (or array of values) from one range to another
 
 result = min_result + (value - min_value)/(max_value - min_value)*(max_result - min_result)
 return result

# %%
api_df = get_data(index=1,lim=100,
start='2023-11-09',
end='2023-11-10')
angles = api_df['meanDirection']
adjusted_angles = map_value(angles, min(angles), max(angles), 0,127)

# %%
xlist = [np.cos(ang) for ang in adjusted_angles]
ylist = [np.sin(ang) for ang in adjusted_angles]
ylist = map_value(ylist, min(ylist), max(ylist), 1,1)
for x, y in zip(xlist, ylist):
  plt.plot([0,x],[0,y])
plt.show()

# %%
def add_pan(filename, track_number, pan_values):
    mid = mido.MidiFile(filename + ".mid")
    track = mid.tracks[track_number]
    current_time = 0
    index = 0
    pan_index = 0
    
    for i in range(len(track)):
        msg = track[i]

        try:
            if msg.type == "note_on":
                # Calculate the panning value based on the note number
                # Example: Panning based on note number (0 to 127)
                        
                panning_value = pan_values[pan_index]

                if msg.time != 0:
                        
                    pan_control = mido.Message('control_change', channel=msg.channel, control=10, value= panning_value, time= msg.time)
                    
                
                    track.insert(index+1, pan_control)
    
                    print(i)
                   
                    if pan_index < len(pan_values)-1:
                        pan_index+=1
        except:
            print("Skipping Message, Non 'Note On' Value")

            

        index+=1
            
            

    mid.save(filename+".mid")
    return mid

# %%
filename= "api_test_wave_music"

api_to_midi(start, end, filename, note_column, velocity_column, time_column, beats,bpm, notes, vel_min, vel_max)

adjusted_angles = map_value(angles, min(angles), max(angles), 0,127)
int_angles = adjusted_angles.astype("int")
add_pan(filename, 1 , int_angles)

#Looks like the panning is working however the ending isnt getting any??
# Out:
# 0
# 2
# 6
# 9
# 11
# 14
# 18
# 20
# 23
# 27
# 30
# 32
# 35
# 38
# 41
# 44
# 47
# 51
# 53
# 56
# 60
# 62
# 65
# 68
# 71
# 74
# 78
# 80
# 83
# 87
# 89
# 92
# 95
# MidiFile(type=1, ticks_per_beat=960, tracks=[
#   MidiTrack([
#     MetaMessage('set_tempo', tempo=1000000, time=0),
#     MetaMessage('end_of_track', time=0)]),
#   MidiTrack([
#     Message('note_on', channel=0, note=40, velocity=118, time=1071),
#     Message('control_change', channel=0, control=10, value=84, time=1071),
#     Message('note_on', channel=0, note=55, velocity=109, time=1185),
#     Message('control_change', channel=0, control=10, value=82, time=1185),
#     Message('note_off', channel=0, note=40, velocity=118, time=735),
#     Message('note_off', channel=0, note=55, velocity=106, time=239),
#     Message('note_on', channel=0, note=55, velocity=106, time=0),
#     Message('control_change', channel=0, control=10, value=59, time=0),
#     Message('note_off', channel=0, note=55, velocity=109, time=928),
#     Message('note_on', channel=0, note=55, velocity=127, time=0),
#     Message('control_change', channel=0, control=10, value=80, time=0),
#     Message('note_on', channel=0, note=64, velocity=118, time=1138),
#     Message('control_change', channel=0, control=10, value=49, time=1138),
#     Message('note_off', channel=0, note=55, velocity=127, time=782),
#     Message('note_on', channel=0, note=55, velocity=115, time=254),
#     Message('control_change', channel=0, control=10, value=68, time=254),
#     Message('note_off', channel=0, note=64, velocity=118, time=884),
#     Message('note_off', channel=0, note=55, velocity=115, time=224),
#     Message('note_on', channel=0, note=55, velocity=115, time=0),
#     Message('control_change', channel=0, control=10, value=52, time=0),
#     Message('note_on', channel=0, note=40, velocity=69, time=1370),
#     Message('control_change', channel=0, control=10, value=63, time=1370),
#     Message('note_off', channel=0, note=55, velocity=115, time=550),
#     Message('note_on', channel=0, note=55, velocity=109, time=615),
#     Message('control_change', channel=0, control=10, value=92, time=615),
#     Message('note_off', channel=0, note=40, velocity=69, time=755),
#     Message('note_off', channel=0, note=55, velocity=109, time=296),
#     Message('note_on', channel=0, note=55, velocity=50, time=0),
#     Message('control_change', channel=0, control=10, value=77, time=0),
#     Message('note_off', channel=0, note=55, velocity=50, time=1190),
#     Message('note_on', channel=0, note=55, velocity=69, time=0),
#     Message('control_change', channel=0, control=10, value=30, time=0),
#     Message('note_on', channel=0, note=57, velocity=81, time=1309),
#     Message('control_change', channel=0, control=10, value=11, time=1309),
#     Message('note_off', channel=0, note=55, velocity=69, time=611),
#     Message('note_on', channel=0, note=69, velocity=102, time=450),
#     Message('control_change', channel=0, control=10, value=75, time=450),
#     Message('note_off', channel=0, note=57, velocity=81, time=859),
#     Message('note_on', channel=0, note=64, velocity=69, time=481),
#     Message('control_change', channel=0, control=10, value=76, time=481),
#     Message('note_off', channel=0, note=69, velocity=102, time=580),
#     Message('note_on', channel=0, note=62, velocity=112, time=754),
#     Message('control_change', channel=0, control=10, value=46, time=754),
#     Message('note_off', channel=0, note=64, velocity=69, time=586),
#     Message('note_on', channel=0, note=69, velocity=97, time=429),
#     Message('control_change', channel=0, control=10, value=81, time=429),
#     Message('note_off', channel=0, note=62, velocity=112, time=905),
#     Message('note_on', channel=0, note=64, velocity=106, time=425),
#     Message('control_change', channel=0, control=10, value=117, time=425),
#     Message('note_off', channel=0, note=69, velocity=97, time=590),
#     Message('note_off', channel=0, note=64, velocity=106, time=1074),
#     Message('note_on', channel=0, note=64, velocity=106, time=0),
#     Message('control_change', channel=0, control=10, value=85, time=0),
#     Message('note_on', channel=0, note=55, velocity=69, time=1623),
#     Message('control_change', channel=0, control=10, value=0, time=1623),
#     Message('note_off', channel=0, note=64, velocity=106, time=297),
#     Message('note_on', channel=0, note=64, velocity=69, time=1156),
#     Message('control_change', channel=0, control=10, value=43, time=1156),
#     Message('note_off', channel=0, note=55, velocity=69, time=467),
#     Message('note_off', channel=0, note=64, velocity=69, time=991),
#     Message('note_on', channel=0, note=64, velocity=109, time=0),
#     Message('control_change', channel=0, control=10, value=46, time=0),
#     Message('note_on', channel=0, note=62, velocity=69, time=1402),
#     Message('control_change', channel=0, control=10, value=66, time=1402),
#     Message('note_off', channel=0, note=64, velocity=109, time=518),
#     Message('note_on', channel=0, note=57, velocity=69, time=971),
#     Message('control_change', channel=0, control=10, value=127, time=971),
#     Message('note_off', channel=0, note=62, velocity=69, time=431),
#     Message('note_on', channel=0, note=62, velocity=109, time=1197),
#     Message('control_change', channel=0, control=10, value=96, time=1197),
#     Message('note_off', channel=0, note=57, velocity=69, time=292),
#     Message('note_on', channel=0, note=69, velocity=109, time=1043),
#     Message('control_change', channel=0, control=10, value=72, time=1043),
#     Message('note_off', channel=0, note=62, velocity=109, time=585),
#     Message('note_on', channel=0, note=62, velocity=112, time=1017),
#     Message('control_change', channel=0, control=10, value=65, time=1017),
#     Message('note_off', channel=0, note=69, velocity=109, time=318),
#     Message('note_off', channel=0, note=62, velocity=112, time=1099),
#     Message('note_on', channel=0, note=62, velocity=115, time=0),
#     Message('control_change', channel=0, control=10, value=83, time=0),
#     Message('note_on', channel=0, note=57, velocity=50, time=1644),
#     Message('control_change', channel=0, control=10, value=80, time=1644),
#     Message('note_off', channel=0, note=62, velocity=115, time=276),
#     Message('note_on', channel=0, note=48, velocity=50, time=1527),
#     Message('control_change', channel=0, control=10, value=72, time=1527),
#     Message('note_off', channel=0, note=57, velocity=50, time=117),
#     Message('note_off', channel=0, note=48, velocity=50, time=1403),
#     Message('note_on', channel=0, note=48, velocity=117, time=0),
#     Message('control_change', channel=0, control=10, value=39, time=0),
#     Message('note_on', channel=0, note=43, velocity=117, time=1463),
#     Message('control_change', channel=0, control=10, value=59, time=1463),
#     Message('note_off', channel=0, note=48, velocity=117, time=457),
#     Message('note_on', channel=0, note=36, velocity=120, time=1074),
#     Message('control_change', channel=0, control=10, value=64, time=1074),
#     Message('note_off', channel=0, note=43, velocity=117, time=389),
#     Message('note_on', channel=0, note=50, velocity=69, time=899),
#     Message('control_change', channel=0, control=10, value=103, time=899),
#     Message('note_off', channel=0, note=36, velocity=120, time=632),
#     Message('note_on', channel=0, note=55, velocity=69, time=548),
#     Message('note_off', channel=0, note=50, velocity=69, time=740),
#     Message('note_on', channel=0, note=62, velocity=69, time=218),
#     Message('note_off', channel=0, note=62, velocity=69, time=866),
#     Message('note_on', channel=0, note=62, velocity=97, time=0),
#     Message('note_off', channel=0, note=55, velocity=69, time=96),
#     Message('note_on', channel=0, note=64, velocity=50, time=692),
#     Message('note_off', channel=0, note=62, velocity=97, time=1087),
#     Message('note_on', channel=0, note=62, velocity=106, time=0),
#     Message('note_off', channel=0, note=64, velocity=50, time=833),
#     Message('note_off', channel=0, note=62, velocity=106, time=28),
#     Message('note_on', channel=0, note=62, velocity=69, time=0),
#     Message('note_on', channel=0, note=57, velocity=118, time=948),
#     Message('note_off', channel=0, note=62, velocity=69, time=972),
#     Message('note_on', channel=0, note=55, velocity=69, time=146),
#     Message('note_off', channel=0, note=57, velocity=118, time=802),
#     Message('note_on', channel=0, note=50, velocity=121, time=223),
#     Message('note_off', channel=0, note=55, velocity=69, time=895),
#     Message('note_off', channel=0, note=50, velocity=121, time=48),
#     Message('note_on', channel=0, note=50, velocity=121, time=0),
#     Message('note_on', channel=0, note=55, velocity=109, time=783),
#     Message('note_on', channel=0, note=57, velocity=109, time=789),
#     Message('note_off', channel=0, note=50, velocity=121, time=348),
#     Message('note_off', channel=0, note=55, velocity=109, time=466),
#     Message('note_on', channel=0, note=55, velocity=109, time=0),
#     Message('note_on', channel=0, note=50, velocity=115, time=762),
#     Message('note_off', channel=0, note=57, velocity=109, time=344),
#     Message('note_off', channel=0, note=50, velocity=115, time=409),
#     Message('note_on', channel=0, note=50, velocity=106, time=0),
#     Message('note_off', channel=0, note=55, velocity=109, time=405),
#     Message('note_off', channel=0, note=50, velocity=106, time=1515),
#     MetaMessage('end_of_track', time=0)])
# ])

# %% [markdown]
# # WORK IN PROGRESS

# %%
# WORK IN PROGRESS TRYING TO SMOOTH THE PANNING SO IT DOESNT FEEL SUDDEN
def add_pan(filename, track_number, pan_values):
    mid = mido.MidiFile(filename + ".mid")
    track = mid.tracks[track_number]
    current_time = 0
    index = 0
    pan_index = 0
    for i in range(len(track)):
        msg = track[i]

        try:
            if msg.type == "note_on":
                # Calculate the panning value based on the note number
                # Example: Panning based on note number (0 to 127)
                for i in range(len(pan_values)):
                    if pan_values[i] >= 63:
                        pan_values[i] = 127
                    else:
                        pan_values[i] = 0
                        
                panning_value = pan_values[pan_index]
                pan_control = mido.Message('control_change', channel=msg.channel, control=10, value= panning_value, time= msg.time)
                
                for num in range(pan_values[pan_index],pan_values[pan_index+1]):
                    print(num)
                    if i == 0:
                        track.insert(0, pan_control)
                    else:
                        msg.time +=1
                        track.insert(index+1,mido.Message('control_change', channel=msg.channel, control=10, value= num, time= 19))
    
               
                if pan_index < len(pan_values)-1:
                    pan_index+=1
        except:
            print("Skipping Message, Non 'Note On' Value")

            

        index+=1
            
            

    mid.save(filename+".mid")
    print(mid)
